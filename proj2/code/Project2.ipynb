# %%
from torch import FloatTensor, LongTensor
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Module(object):
    def forward(self, *input):
        raise NotImplementedError

    def backward(self, *gradwrtoutput):
        raise NotImplementedError

    def param(self):
        return []

# %%
class Linear(Module):
    def __init__(self, in_features, out_features, bias=True):
        super(Linear).__init__()

        self.name = 'Linear'

        self.in_features = in_features
        self.out_features = out_features

        self.weight = FloatTensor(in_features, out_features)
        self.weight_grad = FloatTensor(in_features, out_features)

        if bias:
            self.bias = FloatTensor(out_features)
            self.bias_grad = FloatTensor(out_features)
        else:
            self.bias = None
            self.bias_grad = None

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(0))
        self.weight.uniform_(-stdv, stdv)
        self.weight_grad.fill_(0)
        if self.bias is not None:
            self.bias.uniform_(-stdv, stdv)
            self.bias_grad.fill_(0)

    def forward(self, input):
        # Y = X * W + b
        self.input = input.clone()
        if self.bias is not None:
            return self.input.matmul(self.weight).add(self.bias)
        else:
            return self.input.matmul(self.weight)

    def backward(self, gradwrtoutput):
        # dW = X^T * dL/dY
        self.weight_grad = self.input.t().matmul(gradwrtoutput)
        # db = (dL/dY)^T * 1
        if self.bias is not None:
            self.bias_grad = gradwrtoutput.t().sum(1)
        # dX = dL/dY * W^T
        return gradwrtoutput.matmul(self.weight.t())

    def param(self):
        if self.bias is not None:
            return [(self.weight, self.weight_grad),
                    (self.bias, self.bias_grad)]
        else:
            return [(self.weight, self.weight_grad)]

# %%
class ReLU(Module):
    def __init__(self):
        super(ReLU).__init__()

        self.name = 'ReLU'

    def forward(self, input):
        # Y = max(0,X)
        self.input = input.clone()
        return self.input.mul(self.input.gt(0).float())

    def backward(self, gradwrtoutput):
        if self.input is not None:
            return gradwrtoutput.mul(self.input.gt(0).float())
        else:
            print("Forward First")
            return None

    def param(self):
        return []

# %%
class Tanh(Module):
    def __init__(self):
        super(Tanh).__init__()
        self.name = 'Tanh'

    def forward(self, input):
        # Y = (exp(X) - exp(-X))/(exp(X) + exp(-X))
        self.input = input.clone()
        return self.input.tanh()
        # self.input.masked_fill_(self.input.gt(50), 50)  # prevent overflow
        # return (self.input.exp() - self.input.mul(-1).exp()) / (self.input.exp() + self.input.mul(-1).exp())

    def backward(self, gradwrtoutput):
        # dY/dX = 4/(exp(x) + exp(-x))^2
        if self.input is not None:
            grad = 4. / (self.input.exp() + self.input.mul(-1).exp()).pow(2)
            return gradwrtoutput.mul(grad)
        else:
            print("Forward First")
            return None

    def param(self):
        return []

# %%
class Sequential(Module):
    def __init__(self):
        super(Sequential).__init__()
        self.name = 'Sequential'
        self.module_list = []

    def add(self, *module):
        for m in module:
            self.module_list.append(m)

    def forward(self, input):
        module_input = input.clone()
        for module in self.module_list:
            module_output = module.forward(module_input)
            module_input = module_output
        return module_output

    def backward(self, gradwrtoutput):
        grad = gradwrtoutput
        for module in self.module_list[::-1]:
            grad = module.backward(grad)
        # return grad

    def param(self):
        return [module.param() for module in self.module_list]

# %%
class LossMSE():
    def __init__(self):
        super(LossMSE).__init__()
        self.name = 'LossMSE'

    def forward(self, predict_value, true_value):
        self.predict_value = predict_value
        self.true_value = true_value
        self.loss = (self.predict_value - self.true_value).float().pow(2).mean()
        return self.loss

    def backward(self):
        return 2 * (self.predict_value - self.true_value).float()

# %%
def reshapeLabel(label):
    '''
    Reshape 1-D [0,1,...] to 2-D [[1,-1],[-1,1],...].
    '''
    n = label.size(0)
    y = FloatTensor(n, 2)
    y[:, 0] = 2 * (0.5 - label)
    y[:, 1] = - y[:, 0]
    return y.long()

# %%
X_train = FloatTensor(1000, 2).uniform_(0, 1)
y_label_train = X_train.sub(0.5).pow(2).sum(1).lt(1./2./math.pi).float()
y_train = reshapeLabel(y_label_train)

X_test = FloatTensor(1000, 2).uniform_(0, 1)
y_label_test = X_test.sub(0.5).pow(2).sum(1).lt(1./2./math.pi).float()
y_test = reshapeLabel(y_label_test)

# %%
# Plot 
fig, ax = plt.subplots(1, 2, figsize=(18,8))
zero_index = np.where(y_label_train==0)[0]
one_index = np.where(y_label_train==1)[0]
ax[0].plot(np.array(X_train)[zero_index, 0], np.array(X_train)[zero_index, 1], 'r.', label='zero')
ax[0].plot(np.array(X_train)[one_index, 0], np.array(X_train)[one_index, 1], 'b+', label='one')
ax[0].set_title('Data Distribution in Training Set', size=20)
ax[0].legend();

zero_index = np.where(y_label_test==0)[0]
one_index = np.where(y_label_test==1)[0]
ax[1].plot(np.array(X_test)[zero_index, 0], np.array(X_test)[zero_index, 1], 'r.', label='zero')
ax[1].plot(np.array(X_test)[one_index, 0], np.array(X_test)[one_index, 1], 'b+', label='one')
ax[1].set_title('Data Distribution in Test Set', size=20)
ax[1].legend();

# %%
# Normalization
mu, std = X_train.mean(), X_train.std()
X_train.sub_(mu).div_(std)
X_test.sub_(mu).div_(std);

# %%
train_output = model.forward(X_train)
print("Before Train Error: {:.2%}".format(train_output.max(1)[1].ne(y_train.max(1)[1]).sum()/train_output.size(0)))

# %%
model = Sequential()
#model.add(Linear(2, 25), ReLU(), Linear(25, 2), Tanh())
model.add(Linear(2, 25), ReLU(), 
          Linear(25, 25), ReLU(),
          Linear(25, 25), ReLU(),
          Linear(25, 2), Tanh())

# %%
lr = 0.01
mini_batch_size = 50
epoch = 10

criterion = LossMSE()

error_log4 = []

for e in range(epoch):
    print("******** Begin Epoch {} ********\n".format(e))
    for b in range(0, X_train.size(0), mini_batch_size):
        output = model.forward(X_train.narrow(0, b, mini_batch_size))
        loss = criterion.forward(output, y_train.narrow(0, b, mini_batch_size).float())
        error = output.max(1)[1].ne(y_train.narrow(0, b, mini_batch_size).max(1)[1]).sum()/output.size(0)
        print("Epoch {} Batch {:2.0f}: {:4.2f}, {:6.2%}".format(e, b/mini_batch_size, loss, error))
        l_grad = criterion.backward()
        #print(l_grad)
        model.backward(l_grad)
        for layer in model.param():
            for p in layer:
                p[0].sub_(lr*p[1])
    
    print("\n******** After Epoch {} ********\n".format(e))
    output = model.forward(X_train)
    loss = criterion.forward(output, y_train.float())
    error = output.max(1)[1].ne(y_train.max(1)[1]).sum()/output.size(0)
    error_log4.append(error)
    print("Loss: {:4.2f}, Error: {:6.2%}\n".format(loss, error))
    #print(e, criterion.calculate(model.forward(X_train), y_train.float()))
# Out:
# ******** Begin Epoch 0 ********
#
# Epoch 0 Batch  0: 0.99, 44.00%
# Epoch 0 Batch  1: 0.97, 38.00%
# Epoch 0 Batch  2: 0.98, 42.00%
# Epoch 0 Batch  3: 1.18, 66.00%
# Epoch 0 Batch  4: 1.46, 58.00%
# Epoch 0 Batch  5: 1.00, 50.00%
# Epoch 0 Batch  6: 0.99, 46.00%
# Epoch 0 Batch  7: 1.13, 56.00%
# Epoch 0 Batch  8: 0.96, 40.00%
# Epoch 0 Batch  9: 1.03, 52.00%
# Epoch 0 Batch 10: 0.97, 44.00%
# Epoch 0 Batch 11: 0.97, 50.00%
# Epoch 0 Batch 12: 0.93, 42.00%
# Epoch 0 Batch 13: 1.09, 48.00%
# Epoch 0 Batch 14: 0.97, 46.00%
# Epoch 0 Batch 15: 0.94, 28.00%
# Epoch 0 Batch 16: 1.02, 54.00%
# Epoch 0 Batch 17: 0.93, 46.00%
# Epoch 0 Batch 18: 0.92, 42.00%
# Epoch 0 Batch 19: 1.03, 50.00%
#
# ******** After Epoch 0 ********
#
# Loss: 1.11, Error: 49.90%
#
# ******** Begin Epoch 1 ********
#
# Epoch 1 Batch  0: 1.05, 46.00%
# Epoch 1 Batch  1: 0.99, 54.00%
# Epoch 1 Batch  2: 1.12, 54.00%
# Epoch 1 Batch  3: 1.07, 66.00%
# Epoch 1 Batch  4: 1.27, 58.00%
# Epoch 1 Batch  5: 0.98, 48.00%
# Epoch 1 Batch  6: 0.97, 52.00%
# Epoch 1 Batch  7: 1.28, 56.00%
# Epoch 1 Batch  8: 0.90, 38.00%
# Epoch 1 Batch  9: 0.81, 32.00%
# Epoch 1 Batch 10: 0.97, 46.00%
# Epoch 1 Batch 11: 0.87, 32.00%
# Epoch 1 Batch 12: 0.86, 28.00%
# Epoch 1 Batch 13: 1.21, 48.00%
# Epoch 1 Batch 14: 0.86, 34.00%
# Epoch 1 Batch 15: 0.80, 34.00%
# Epoch 1 Batch 16: 0.97, 46.00%
# Epoch 1 Batch 17: 1.21, 42.00%
# Epoch 1 Batch 18: 0.75, 26.00%
# Epoch 1 Batch 19: 0.97, 38.00%
#
# ******** After Epoch 1 ********
#
# Loss: 0.94, Error: 43.00%
#
# ******** Begin Epoch 2 ********
#
# Epoch 2 Batch  0: 0.91, 40.00%
# Epoch 2 Batch  1: 0.83, 26.00%
# Epoch 2 Batch  2: 0.80, 28.00%
# Epoch 2 Batch  3: 1.18, 42.00%
# Epoch 2 Batch  4: 0.59, 18.00%
# Epoch 2 Batch  5: 0.54, 16.00%
# Epoch 2 Batch  6: 0.95, 30.00%
# Epoch 2 Batch  7: 0.56, 20.00%
# Epoch 2 Batch  8: 0.66, 24.00%
# Epoch 2 Batch  9: 0.49, 16.00%
# Epoch 2 Batch 10: 1.02, 28.00%
# Epoch 2 Batch 11: 0.67, 26.00%
# Epoch 2 Batch 12: 0.36, 10.00%
# Epoch 2 Batch 13: 0.83, 24.00%
# Epoch 2 Batch 14: 0.50, 16.00%
# Epoch 2 Batch 15: 0.95, 32.00%
# Epoch 2 Batch 16: 0.88, 30.00%
# Epoch 2 Batch 17: 1.04, 32.00%
# Epoch 2 Batch 18: 0.83, 32.00%
# Epoch 2 Batch 19: 1.38, 40.00%
#
# ******** After Epoch 2 ********
#
# Loss: 0.67, Error: 21.10%
#
# ******** Begin Epoch 3 ********
#
# Epoch 3 Batch  0: 0.71, 22.00%
# Epoch 3 Batch  1: 0.72, 28.00%
# Epoch 3 Batch  2: 0.64, 20.00%
# Epoch 3 Batch  3: 0.68, 24.00%
# Epoch 3 Batch  4: 1.18, 46.00%
# Epoch 3 Batch  5: 1.02, 32.00%
# Epoch 3 Batch  6: 1.45, 58.00%
# Epoch 3 Batch  7: 1.23, 34.00%
# Epoch 3 Batch  8: 0.40, 12.00%
# Epoch 3 Batch  9: 0.54, 20.00%
# Epoch 3 Batch 10: 0.82, 28.00%
# Epoch 3 Batch 11: 0.63, 24.00%
# Epoch 3 Batch 12: 0.25,  6.00%
# Epoch 3 Batch 13: 0.29,  8.00%
# Epoch 3 Batch 14: 0.35, 10.00%
# Epoch 3 Batch 15: 0.83, 32.00%
# Epoch 3 Batch 16: 1.33, 40.00%
# Epoch 3 Batch 17: 0.85, 30.00%
# Epoch 3 Batch 18: 0.60, 20.00%
# Epoch 3 Batch 19: 0.86, 32.00%
#
# ******** After Epoch 3 ********
#
# Loss: 0.43, Error: 13.10%
#
# ******** Begin Epoch 4 ********
#
# Epoch 4 Batch  0: 0.49, 16.00%
# Epoch 4 Batch  1: 0.48, 16.00%
# Epoch 4 Batch  2: 0.39, 12.00%
# Epoch 4 Batch  3: 0.39, 14.00%
# Epoch 4 Batch  4: 0.38, 14.00%
# Epoch 4 Batch  5: 0.21,  4.00%
# Epoch 4 Batch  6: 0.45, 18.00%
# Epoch 4 Batch  7: 1.30, 38.00%
# Epoch 4 Batch  8: 0.73, 22.00%
# Epoch 4 Batch  9: 0.67, 22.00%
# Epoch 4 Batch 10: 0.58, 18.00%
# Epoch 4 Batch 11: 0.54, 16.00%
# Epoch 4 Batch 12: 0.36, 14.00%
# Epoch 4 Batch 13: 0.28, 12.00%
# Epoch 4 Batch 14: 0.35, 10.00%
# Epoch 4 Batch 15: 0.73, 24.00%
# Epoch 4 Batch 16: 1.29, 40.00%
# Epoch 4 Batch 17: 0.72, 26.00%
# Epoch 4 Batch 18: 0.43, 14.00%
# Epoch 4 Batch 19: 0.41, 12.00%
#
# ******** After Epoch 4 ********
#
# Loss: 0.28, Error:  7.70%
#
# ******** Begin Epoch 5 ********
#
# Epoch 5 Batch  0: 0.25,  6.00%
# Epoch 5 Batch  1: 0.18,  4.00%
# Epoch 5 Batch  2: 0.42, 16.00%
# Epoch 5 Batch  3: 0.45, 18.00%
# Epoch 5 Batch  4: 1.18, 42.00%
# Epoch 5 Batch  5: 0.67, 20.00%
# Epoch 5 Batch  6: 0.82, 30.00%
# Epoch 5 Batch  7: 1.20, 34.00%
# Epoch 5 Batch  8: 0.15,  4.00%
# Epoch 5 Batch  9: 0.20,  6.00%
# Epoch 5 Batch 10: 0.41, 16.00%
# Epoch 5 Batch 11: 0.48, 18.00%
# Epoch 5 Batch 12: 0.33,  8.00%
# Epoch 5 Batch 13: 0.38, 10.00%
# Epoch 5 Batch 14: 0.35, 12.00%
# Epoch 5 Batch 15: 0.39, 12.00%
# Epoch 5 Batch 16: 0.42, 12.00%
# Epoch 5 Batch 17: 0.51, 16.00%
# Epoch 5 Batch 18: 0.39, 10.00%
# Epoch 5 Batch 19: 0.15,  4.00%
#
# ******** After Epoch 5 ********
#
# Loss: 0.16, Error:  6.00%
#
# ******** Begin Epoch 6 ********
#
# Epoch 6 Batch  0: 0.15,  6.00%
# Epoch 6 Batch  1: 0.34, 12.00%
# Epoch 6 Batch  2: 0.46, 14.00%
# Epoch 6 Batch  3: 0.34, 12.00%
# Epoch 6 Batch  4: 0.41, 14.00%
# Epoch 6 Batch  5: 0.23, 10.00%
# Epoch 6 Batch  6: 0.28, 12.00%
# Epoch 6 Batch  7: 0.37, 12.00%
# Epoch 6 Batch  8: 0.14,  4.00%
# Epoch 6 Batch  9: 0.13,  4.00%
# Epoch 6 Batch 10: 0.14,  4.00%
# Epoch 6 Batch 11: 0.24,  8.00%
# Epoch 6 Batch 12: 0.04,  0.00%
# Epoch 6 Batch 13: 0.16,  6.00%
# Epoch 6 Batch 14: 0.20,  6.00%
# Epoch 6 Batch 15: 0.95, 28.00%
# Epoch 6 Batch 16: 0.75, 28.00%
# Epoch 6 Batch 17: 0.68, 20.00%
# Epoch 6 Batch 18: 0.55, 20.00%
# Epoch 6 Batch 19: 0.39, 12.00%
#
# ******** After Epoch 6 ********
#
# Loss: 0.31, Error: 10.50%
#
# ******** Begin Epoch 7 ********
#
# Epoch 7 Batch  0: 0.23,  6.00%
# Epoch 7 Batch  1: 0.35, 12.00%
# Epoch 7 Batch  2: 0.53, 20.00%
# Epoch 7 Batch  3: 0.49, 20.00%
# Epoch 7 Batch  4: 0.93, 30.00%
# Epoch 7 Batch  5: 0.73, 24.00%
# Epoch 7 Batch  6: 0.39, 10.00%
# Epoch 7 Batch  7: 0.33, 12.00%
# Epoch 7 Batch  8: 0.10,  2.00%
# Epoch 7 Batch  9: 0.13,  4.00%
# Epoch 7 Batch 10: 0.30, 10.00%
# Epoch 7 Batch 11: 0.45, 18.00%
# Epoch 7 Batch 12: 0.27,  8.00%
# Epoch 7 Batch 13: 0.19,  8.00%
# Epoch 7 Batch 14: 0.18,  6.00%
# Epoch 7 Batch 15: 0.23,  6.00%
# Epoch 7 Batch 16: 0.25, 10.00%
# Epoch 7 Batch 17: 0.39, 16.00%
# Epoch 7 Batch 18: 0.20,  6.00%
# Epoch 7 Batch 19: 0.36, 14.00%
#
# ******** After Epoch 7 ********
#
# Loss: 0.31, Error: 11.20%
#
# ******** Begin Epoch 8 ********
#
# Epoch 8 Batch  0: 0.34, 10.00%
# Epoch 8 Batch  1: 0.22, 10.00%
# Epoch 8 Batch  2: 0.38, 12.00%
# Epoch 8 Batch  3: 0.22,  8.00%
# Epoch 8 Batch  4: 0.24,  8.00%
# Epoch 8 Batch  5: 0.38, 14.00%
# Epoch 8 Batch  6: 0.36, 12.00%
# Epoch 8 Batch  7: 0.31, 10.00%
# Epoch 8 Batch  8: 0.07,  4.00%
# Epoch 8 Batch  9: 0.08,  2.00%
# Epoch 8 Batch 10: 0.17,  6.00%
# Epoch 8 Batch 11: 0.22, 12.00%
# Epoch 8 Batch 12: 0.04,  2.00%
# Epoch 8 Batch 13: 0.11,  4.00%
# Epoch 8 Batch 14: 0.21, 10.00%
# Epoch 8 Batch 15: 0.24,  6.00%
# Epoch 8 Batch 16: 0.38, 12.00%
# Epoch 8 Batch 17: 0.45, 16.00%
# Epoch 8 Batch 18: 0.39, 14.00%
# Epoch 8 Batch 19: 0.38, 12.00%
#
# ******** After Epoch 8 ********
#
# Loss: 0.31, Error:  9.40%
#
# ******** Begin Epoch 9 ********
#
# Epoch 9 Batch  0: 0.27,  8.00%
# Epoch 9 Batch  1: 0.26, 10.00%
# Epoch 9 Batch  2: 0.38, 12.00%
# Epoch 9 Batch  3: 0.23,  8.00%
# Epoch 9 Batch  4: 0.34, 12.00%
# Epoch 9 Batch  5: 0.18,  6.00%
# Epoch 9 Batch  6: 0.29, 12.00%
# Epoch 9 Batch  7: 0.57, 14.00%
# Epoch 9 Batch  8: 0.35, 12.00%
# Epoch 9 Batch  9: 0.38, 10.00%
# Epoch 9 Batch 10: 0.21, 10.00%
# Epoch 9 Batch 11: 0.18,  4.00%
# Epoch 9 Batch 12: 0.02,  0.00%
# Epoch 9 Batch 13: 0.18,  6.00%
# Epoch 9 Batch 14: 0.20,  6.00%
# Epoch 9 Batch 15: 0.48, 12.00%
# Epoch 9 Batch 16: 0.17,  6.00%
# Epoch 9 Batch 17: 0.12,  6.00%
# Epoch 9 Batch 18: 0.26, 10.00%
# Epoch 9 Batch 19: 0.33, 10.00%
#
# ******** After Epoch 9 ********
#
# Loss: 0.26, Error:  8.60%

# %%
train_output = model.forward(X_train)
print("Train Error: {:.2%}".format(train_output.max(1)[1].ne(y_train.max(1)[1]).sum()/train_output.size(0)))

test_output = model.forward(X_test)
print("Test Error: {:.2%}".format(test_output.max(1)[1].ne(y_test.max(1)[1]).sum()/test_output.size(0)))
# Out:
# Train Error: 8.60%
# Test Error: 9.00%

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), np.array(error_log)*100)
plt.plot(range(1,11), np.array(error_log1)*100)
plt.plot(range(1,11), np.array(error_log2)*100)
plt.plot(range(1,11), np.array(error_log3)*100)
plt.plot(range(1,11), np.array(error_log4)*100)
plt.xlim(1,10)
plt.grid()
plt.xlabel("Epoch", size=20)
plt.ylabel("Error Rate(%)", size=20)
plt.title("Training Error Log", size=30)
plt.savefig("training.jpg")  ;

# %% [markdown]
# ---

# %%
import torch
from torch import nn, optim 
from torch.nn import functional as F 
from torch.autograd import Variable

# %%
X_train = FloatTensor(1000, 2).uniform_(0, 1)
y_label_train = X_train.sub(0.5).pow(2).sum(1).lt(1./2./math.pi).float()
y_train = reshapeLabel(y_label_train)

X_test = FloatTensor(1000, 2).uniform_(0, 1)
y_label_test = X_test.sub(0.5).pow(2).sum(1).lt(1./2./math.pi).float()
y_test = reshapeLabel(y_label_test)

# %%
# convert to Variable
X_train, y_train = Variable(X_train), Variable(y_train)
X_test, y_test = Variable(X_test), Variable(y_test)

# %%
mu, std = X_train.mean(), X_train.std()
X_train.sub_(mu).div_(std)
X_test.sub_(mu).div_(std);

y_train = y_train.float()
y_test = y_test.float()

# %%
train_output = model.forward(X_train)
print("Before Train Error: {:.2%}".format(float(train_output.max(1)[1].ne(y_train.max(1)[1]).sum())/train_output.size(0)))
# Out:
# Before Train Error: 24.80%

# %%
model = nn.Sequential(
        nn.Linear(2,25),
        nn.ReLU(),
        nn.Linear(25,25),
        nn.ReLU(),
        nn.Linear(25,25),
        nn.ReLU(),
        nn.Linear(25,2),
        nn.Tanh(),
)

# %%
# %%time
lr = 0.01
batch_size = 50
nb_epochs = 10

criterion = nn.MSELoss()

optimizer = optim.SGD(model.parameters(), lr=lr)

for k in range(nb_epochs):
    print("******** Begin Epoch {} ********\n".format(k))
    for b in range(0, X_train.size(0), batch_size):
        output = model.forward(X_train.narrow(0, b, batch_size)) 
        loss = criterion(output , y_train.narrow(0, b, batch_size))
        error = float(output.max(1)[1].ne(y_train.narrow(0, b, batch_size).max(1)[1]).sum())/output.size(0)
        print("Epoch {} Batch {:2.0f}: {:4.2f}, {:6.2%}".format(k, b/batch_size, loss.data[0], error))
        model.zero_grad()
        loss.backward()
        optimizer.step()
    
    print("\n******** After Epoch {} ********\n".format(k))
    output = model.forward(X_train)
    loss = criterion(output, y_train.float())
    error = float(output.max(1)[1].ne(y_train.max(1)[1]).sum())/output.size(0)
    print("Loss: {:4.2f}, Error: {:6.2%}\n".format(loss.data[0], error))
# Out:
# ******** Begin Epoch 0 ********
#
# Epoch 0 Batch  0: 1.00, 46.00%
# Epoch 0 Batch  1: 1.00, 44.00%
# Epoch 0 Batch  2: 1.01, 56.00%
# Epoch 0 Batch  3: 1.03, 68.00%
# Epoch 0 Batch  4: 1.01, 54.00%
# Epoch 0 Batch  5: 1.01, 56.00%
# Epoch 0 Batch  6: 1.01, 58.00%
# Epoch 0 Batch  7: 1.01, 56.00%
# Epoch 0 Batch  8: 1.01, 50.00%
# Epoch 0 Batch  9: 1.00, 50.00%
# Epoch 0 Batch 10: 1.00, 48.00%
# Epoch 0 Batch 11: 1.00, 44.00%
# Epoch 0 Batch 12: 1.01, 52.00%
# Epoch 0 Batch 13: 1.00, 44.00%
# Epoch 0 Batch 14: 1.00, 44.00%
# Epoch 0 Batch 15: 1.01, 52.00%
# Epoch 0 Batch 16: 1.00, 40.00%
# Epoch 0 Batch 17: 1.01, 46.00%
# Epoch 0 Batch 18: 1.00, 38.00%
# Epoch 0 Batch 19: 1.00, 36.00%
#
# ******** After Epoch 0 ********
#
# Loss: 1.00, Error: 16.10%
#
# ******** Begin Epoch 1 ********
#
# Epoch 1 Batch  0: 1.00, 40.00%
# Epoch 1 Batch  1: 0.99, 36.00%
# Epoch 1 Batch  2: 1.00, 50.00%
# Epoch 1 Batch  3: 1.00, 50.00%
# Epoch 1 Batch  4: 1.00, 48.00%
# Epoch 1 Batch  5: 1.01, 44.00%
# Epoch 1 Batch  6: 0.99, 38.00%
# Epoch 1 Batch  7: 0.99, 36.00%
# Epoch 1 Batch  8: 1.00, 46.00%
# Epoch 1 Batch  9: 0.99, 36.00%
# Epoch 1 Batch 10: 0.99, 40.00%
# Epoch 1 Batch 11: 0.98, 22.00%
# Epoch 1 Batch 12: 1.00, 38.00%
# Epoch 1 Batch 13: 0.99, 26.00%
# Epoch 1 Batch 14: 0.99, 30.00%
# Epoch 1 Batch 15: 1.00, 40.00%
# Epoch 1 Batch 16: 0.99, 34.00%
# Epoch 1 Batch 17: 1.00, 34.00%
# Epoch 1 Batch 18: 0.99, 34.00%
# Epoch 1 Batch 19: 0.99, 32.00%
#
# ******** After Epoch 1 ********
#
# Loss: 0.99, Error:  6.60%
#
# ******** Begin Epoch 2 ********
#
# Epoch 2 Batch  0: 1.00, 36.00%
# Epoch 2 Batch  1: 0.99, 20.00%
# Epoch 2 Batch  2: 0.99, 40.00%
# Epoch 2 Batch  3: 0.99, 32.00%
# Epoch 2 Batch  4: 1.00, 34.00%
# Epoch 2 Batch  5: 1.00, 44.00%
# Epoch 2 Batch  6: 0.98, 20.00%
# Epoch 2 Batch  7: 0.98, 28.00%
# Epoch 2 Batch  8: 1.00, 42.00%
# Epoch 2 Batch  9: 0.98, 22.00%
# Epoch 2 Batch 10: 0.99, 32.00%
# Epoch 2 Batch 11: 0.98, 20.00%
# Epoch 2 Batch 12: 0.99, 32.00%
# Epoch 2 Batch 13: 0.98, 26.00%
# Epoch 2 Batch 14: 0.98, 28.00%
# Epoch 2 Batch 15: 0.99, 28.00%
# Epoch 2 Batch 16: 0.99, 36.00%
# Epoch 2 Batch 17: 1.00, 38.00%
# Epoch 2 Batch 18: 0.99, 40.00%
# Epoch 2 Batch 19: 0.99, 38.00%
#
# ******** After Epoch 2 ********
#
# Loss: 0.99, Error:  6.40%
#
# ******** Begin Epoch 3 ********
#
# Epoch 3 Batch  0: 0.99, 42.00%
# Epoch 3 Batch  1: 0.98, 28.00%
# Epoch 3 Batch  2: 0.98, 24.00%
# Epoch 3 Batch  3: 0.98, 24.00%
# Epoch 3 Batch  4: 0.99, 36.00%
# Epoch 3 Batch  5: 1.00, 42.00%
# Epoch 3 Batch  6: 0.98, 24.00%
# Epoch 3 Batch  7: 0.98, 30.00%
# Epoch 3 Batch  8: 0.99, 46.00%
# Epoch 3 Batch  9: 0.98, 30.00%
# Epoch 3 Batch 10: 0.99, 34.00%
# Epoch 3 Batch 11: 0.97, 24.00%
# Epoch 3 Batch 12: 0.99, 38.00%
# Epoch 3 Batch 13: 0.97, 28.00%
# Epoch 3 Batch 14: 0.98, 36.00%
# Epoch 3 Batch 15: 0.98, 34.00%
# Epoch 3 Batch 16: 0.98, 42.00%
# Epoch 3 Batch 17: 0.99, 50.00%
# Epoch 3 Batch 18: 0.99, 48.00%
# Epoch 3 Batch 19: 0.98, 44.00%
#
# ******** After Epoch 3 ********
#
# Loss: 0.98, Error: 11.30%
#
# ******** Begin Epoch 4 ********
#
# Epoch 4 Batch  0: 0.99, 44.00%
# Epoch 4 Batch  1: 0.98, 34.00%
# Epoch 4 Batch  2: 0.98, 24.00%
# Epoch 4 Batch  3: 0.97, 24.00%
# Epoch 4 Batch  4: 0.99, 42.00%
# Epoch 4 Batch  5: 1.00, 48.00%
# Epoch 4 Batch  6: 0.97, 24.00%
# Epoch 4 Batch  7: 0.97, 32.00%
# Epoch 4 Batch  8: 0.99, 50.00%
# Epoch 4 Batch  9: 0.97, 32.00%
# Epoch 4 Batch 10: 0.99, 42.00%
# Epoch 4 Batch 11: 0.96, 28.00%
# Epoch 4 Batch 12: 0.98, 42.00%
# Epoch 4 Batch 13: 0.97, 30.00%
# Epoch 4 Batch 14: 0.97, 36.00%
# Epoch 4 Batch 15: 0.97, 34.00%
# Epoch 4 Batch 16: 0.97, 42.00%
# Epoch 4 Batch 17: 0.99, 50.00%
# Epoch 4 Batch 18: 0.98, 50.00%
# Epoch 4 Batch 19: 0.98, 46.00%
#
# ******** After Epoch 4 ********
#
# Loss: 0.98, Error: 14.40%
#
# ******** Begin Epoch 5 ********
#
# Epoch 5 Batch  0: 0.99, 48.00%
# Epoch 5 Batch  1: 0.98, 34.00%
# Epoch 5 Batch  2: 0.97, 26.00%
# Epoch 5 Batch  3: 0.96, 24.00%
# Epoch 5 Batch  4: 0.98, 44.00%
# Epoch 5 Batch  5: 0.99, 50.00%
# Epoch 5 Batch  6: 0.97, 26.00%
# Epoch 5 Batch  7: 0.96, 36.00%
# Epoch 5 Batch  8: 0.99, 50.00%
# Epoch 5 Batch  9: 0.97, 34.00%
# Epoch 5 Batch 10: 0.98, 42.00%
# Epoch 5 Batch 11: 0.96, 30.00%
# Epoch 5 Batch 12: 0.98, 42.00%
# Epoch 5 Batch 13: 0.96, 30.00%
# Epoch 5 Batch 14: 0.97, 42.00%
# Epoch 5 Batch 15: 0.97, 34.00%
# Epoch 5 Batch 16: 0.97, 42.00%
# Epoch 5 Batch 17: 0.98, 48.00%
# Epoch 5 Batch 18: 0.98, 48.00%
# Epoch 5 Batch 19: 0.97, 46.00%
#
# ******** After Epoch 5 ********
#
# Loss: 0.97, Error: 13.90%
#
# ******** Begin Epoch 6 ********
#
# Epoch 6 Batch  0: 0.99, 46.00%
# Epoch 6 Batch  1: 0.97, 32.00%
# Epoch 6 Batch  2: 0.97, 28.00%
# Epoch 6 Batch  3: 0.96, 24.00%
# Epoch 6 Batch  4: 0.98, 44.00%
# Epoch 6 Batch  5: 0.99, 50.00%
# Epoch 6 Batch  6: 0.96, 24.00%
# Epoch 6 Batch  7: 0.96, 36.00%
# Epoch 6 Batch  8: 0.98, 48.00%
# Epoch 6 Batch  9: 0.96, 36.00%
# Epoch 6 Batch 10: 0.98, 42.00%
# Epoch 6 Batch 11: 0.95, 30.00%
# Epoch 6 Batch 12: 0.97, 42.00%
# Epoch 6 Batch 13: 0.96, 26.00%
# Epoch 6 Batch 14: 0.96, 34.00%
# Epoch 6 Batch 15: 0.96, 32.00%
# Epoch 6 Batch 16: 0.96, 42.00%
# Epoch 6 Batch 17: 0.98, 46.00%
# Epoch 6 Batch 18: 0.97, 46.00%
# Epoch 6 Batch 19: 0.97, 44.00%
#
# ******** After Epoch 6 ********
#
# Loss: 0.97, Error: 11.60%
#
# ******** Begin Epoch 7 ********
#
# Epoch 7 Batch  0: 0.98, 44.00%
# Epoch 7 Batch  1: 0.97, 32.00%
# Epoch 7 Batch  2: 0.97, 26.00%
# Epoch 7 Batch  3: 0.95, 24.00%
# Epoch 7 Batch  4: 0.98, 44.00%
# Epoch 7 Batch  5: 0.98, 42.00%
# Epoch 7 Batch  6: 0.96, 22.00%
# Epoch 7 Batch  7: 0.95, 36.00%
# Epoch 7 Batch  8: 0.98, 44.00%
# Epoch 7 Batch  9: 0.96, 32.00%
# Epoch 7 Batch 10: 0.97, 40.00%
# Epoch 7 Batch 11: 0.95, 28.00%
# Epoch 7 Batch 12: 0.97, 40.00%
# Epoch 7 Batch 13: 0.95, 26.00%
# Epoch 7 Batch 14: 0.96, 28.00%
# Epoch 7 Batch 15: 0.95, 30.00%
# Epoch 7 Batch 16: 0.96, 36.00%
# Epoch 7 Batch 17: 0.98, 38.00%
# Epoch 7 Batch 18: 0.97, 38.00%
# Epoch 7 Batch 19: 0.96, 42.00%
#
# ******** After Epoch 7 ********
#
# Loss: 0.96, Error:  8.60%
#
# ******** Begin Epoch 8 ********
#
# Epoch 8 Batch  0: 0.98, 42.00%
# Epoch 8 Batch  1: 0.96, 30.00%
# Epoch 8 Batch  2: 0.96, 24.00%
# Epoch 8 Batch  3: 0.95, 22.00%
# Epoch 8 Batch  4: 0.97, 42.00%
# Epoch 8 Batch  5: 0.98, 40.00%
# Epoch 8 Batch  6: 0.95, 22.00%
# Epoch 8 Batch  7: 0.95, 32.00%
# Epoch 8 Batch  8: 0.97, 40.00%
# Epoch 8 Batch  9: 0.96, 32.00%
# Epoch 8 Batch 10: 0.97, 34.00%
# Epoch 8 Batch 11: 0.94, 24.00%
# Epoch 8 Batch 12: 0.96, 40.00%
# Epoch 8 Batch 13: 0.94, 26.00%
# Epoch 8 Batch 14: 0.95, 22.00%
# Epoch 8 Batch 15: 0.95, 30.00%
# Epoch 8 Batch 16: 0.95, 36.00%
# Epoch 8 Batch 17: 0.97, 38.00%
# Epoch 8 Batch 18: 0.96, 38.00%
# Epoch 8 Batch 19: 0.96, 38.00%
#
# ******** After Epoch 8 ********
#
# Loss: 0.96, Error:  5.80%
#
# ******** Begin Epoch 9 ********
#
# Epoch 9 Batch  0: 0.97, 42.00%
# Epoch 9 Batch  1: 0.96, 28.00%
# Epoch 9 Batch  2: 0.96, 22.00%
# Epoch 9 Batch  3: 0.94, 20.00%
# Epoch 9 Batch  4: 0.97, 36.00%
# Epoch 9 Batch  5: 0.97, 40.00%
# Epoch 9 Batch  6: 0.94, 22.00%
# Epoch 9 Batch  7: 0.94, 32.00%
# Epoch 9 Batch  8: 0.97, 38.00%
# Epoch 9 Batch  9: 0.95, 28.00%
# Epoch 9 Batch 10: 0.97, 28.00%
# Epoch 9 Batch 11: 0.94, 22.00%
# Epoch 9 Batch 12: 0.96, 38.00%
# Epoch 9 Batch 13: 0.94, 26.00%
# Epoch 9 Batch 14: 0.94, 22.00%
# Epoch 9 Batch 15: 0.94, 22.00%
# Epoch 9 Batch 16: 0.95, 32.00%
# Epoch 9 Batch 17: 0.97, 28.00%
# Epoch 9 Batch 18: 0.96, 38.00%
# Epoch 9 Batch 19: 0.95, 38.00%
#
# ******** After Epoch 9 ********
#
# Loss: 0.95, Error:  3.60%
#
# CPU times: user 231 ms, sys: 27.5 ms, total: 259 ms
# Wall time: 134 ms

# %%
train_output = model.forward(X_train)
print("Train Error: {:.2%}".format(float(train_output.max(1)[1].ne(y_train.max(1)[1]).sum())/train_output.size(0)))

test_output = model.forward(X_test)
print("Test Error: {:.2%}".format(float(test_output.max(1)[1].ne(y_test.max(1)[1]).sum())/test_output.size(0)))
# Out:
# Train Error: 3.60%
# Test Error: 8.50%
